# %% [markdown]
# # Copy Balanced Mini Crops Set to GPU SageMaker
#
# From S3 `s3://gsv-crops2/mini-crops-labeled/balanced`
# Into the mini-balanced-images folder

# %%
import os
import s3fs # for reading from S3FileSystem

# %%
import shutil
shutil.rmtree('/home/ec2-user/SageMaker/classify-streetview/mini-balanced-images')

# %%
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/classify-streetview/mini-crops'

# %%
# !aws s3 cp s3://gsv-crops2/mini-crops-labeled/balanced /home/ec2-user/SageMaker/classify-streetview/mini-balanced-images --recursive
# Out:
# download: s3://gsv-crops2/mini-crops-labeled/balanced/test/0_missing/1297_135_A.jpg to ../mini-balanced-images/test/0_missing/1297_135_A.jpg
# download: s3://gsv-crops2/mini-crops-labeled/balanced/test/0_missing/12270_135_D.jpg to ../mini-balanced-images/test/0_missing/12270_135_D.jpg
# download: s3://gsv-crops2/mini-crops-labeled/balanced/test/0_missing/16125_45_E.jpg to ../mini-balanced-images/test/0_missing/16125_45_E.jpg
# download: s3://gsv-crops2/mini-crops-labeled/balanced/test/0_missing/12251_135_F.jpg to ../mini-balanced-images/test/0_missing/12251_135_F.jpg
# download: s3://gsv-crops2/mini-crops-labeled/balanced/test/0_missing/17033_45_A.jpg to ../mini-balanced-images/test/0_missing/17033_45_A.jpg
# download: s3://gsv-crops2/mini-crops-labeled/balanced/test/0_missing/12251_135_E.jpg to ../mini-balanced-images/test/0_missing/12251_135_E.jpg
# ...

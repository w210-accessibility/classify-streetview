# %% [markdown]
# # Frame as a Binary Classification - Crossing vs Null
#
# * Idea is that we can curate images that contain something "interesting"
# * Then we can try another model that chooses between missing vs present
# * Alternatively, we have humans work

# %%
import pandas as pd
import numpy as np
import os
import boto3
import s3fs # for reading from S3FileSystem
import json # for working with JSON files 
import mini_utils
from datetime import datetime

import matplotlib.pyplot as plt


pd.set_option('max_colwidth', -1)

# %% [markdown]
# # Load Image CSV Info

# %%
df_all = pd.read_csv('imgid_groundtruth_trainvaltest.csv')
df_all.head()
# Out:
#    img_id  heading crop_num         jpg_name  present_ramp  missing_ramp  \
# 0  10007   225      C        10007_225_C.jpg  1.0           0.0
# 1  10007   315      C        10007_315_C.jpg  1.0           0.0
# 2  10007   45       C        10007_45_C.jpg   0.0           0.0
# 3  10007   135      C        10007_135_C.jpg  0.0           0.0
# 4  10013   225      C        10013_225_C.jpg  0.0           0.0
#
#    total_count  includes_both ground_truth train/val/test
# 0  1.0          False          present      train
# 1  1.0          False          present      train
# 2  0.0          False          1_null       train
# 3  0.0          False          1_null       train
# 4  0.0          False          1_null       validation

# %%
df_all.groupby(['train/val/test', 'ground_truth'])['jpg_name'].count().reset_index()
# Out:
#    train/val/test      ground_truth  jpg_name
# 0   test           1_null            1151
# 1   test           multiple_present  21
# 2   test           only_missing      29
# 3   test           present           287
# 4   train          1_null            6621
# 5   train          multiple_present  136
# 6   train          only_missing      75
# 7   train          present           1712
# 8   validation     1_null            1152
# 9   validation     multiple_present  14
# 10  validation     only_missing      25
# 11  validation     present           297

# %%
ground_truth_dict = {'0_crossing' : ['only_missing', 'present', 'multiple_present'],
    '1_null' : ['1_null']
}

# %% [markdown]
# # List for Training

# %%
df_train = df_all.loc[df_all['train/val/test'] == 'train']
df_train_sample = mini_utils.sample_rows(df_train, 2200, ground_truth_dict)
df_train_sample['folder_label'].value_counts()
# Out:
# 0_crossing -> ['only_missing', 'present', 'multiple_present']
# 1_null -> ['1_null']
# 1_null        2200
# 0_crossing    1923
# Name: folder_label, dtype: int64

# %%
df_val = df_all.loc[df_all['train/val/test'] == 'validation']
df_val_sample = mini_utils.sample_rows(df_val, 400, ground_truth_dict)
df_val_sample['folder_label'].value_counts()
# Out:
# 0_crossing -> ['only_missing', 'present', 'multiple_present']
# 1_null -> ['1_null']
# 1_null        400
# 0_crossing    336
# Name: folder_label, dtype: int64

# %%
df_test = df_all.loc[df_all['train/val/test'] == 'test']
df_test_sample = mini_utils.sample_rows(df_test, 400, ground_truth_dict)
df_test_sample['folder_label'].value_counts()
# Out:
# 0_crossing -> ['only_missing', 'present', 'multiple_present']
# 1_null -> ['1_null']
# 1_null        400
# 0_crossing    337
# Name: folder_label, dtype: int64

# %%
df_transfer = pd.concat([df_train_sample, df_val_sample, df_test_sample])
print(df_transfer.shape)
df_transfer.head()
# Out:
# (5596, 11)
#     img_id  heading crop_num         jpg_name  present_ramp  missing_ramp  \
# 0   10007   225      C        10007_225_C.jpg  1.0           0.0
# 1   10007   315      C        10007_315_C.jpg  1.0           0.0
# 11  10018   135      C        10018_135_C.jpg  1.0           0.0
# 15  10039   135      C        10039_135_C.jpg  1.0           0.0
# 17  10076   315      C        10076_315_C.jpg  2.0           0.0
#
#     total_count  includes_both      ground_truth train/val/test folder_label
# 0   1.0          False          present           train          0_crossing
# 1   1.0          False          present           train          0_crossing
# 11  1.0          False          present           train          0_crossing
# 15  1.0          False          present           train          0_crossing
# 17  2.0          False          multiple_present  train          0_crossing

# %%
df_transfer.groupby(['train/val/test', 'folder_label'])['jpg_name'].count().reset_index()
# Out:
#   train/val/test folder_label  jpg_name
# 0  test           0_crossing   337
# 1  test           1_null       400
# 2  train          0_crossing   1923
# 3  train          1_null       2200
# 4  validation     0_crossing   336
# 5  validation     1_null       400

# %%
df_transfer.to_csv('crossing-null-split-img-details.csv', index = False)

# %% [markdown]
# # Specify the destination Path
# * jpg_name
# * train/val/test
# * folder_label

# %%
df_transfer['original_image_path'] = 'mini-crops/' + df_transfer['jpg_name']
df_transfer['new_image_path'] = 'mini-crops-labeled/crossing-null/' + df_transfer['train/val/test'] + '/' + df_transfer['folder_label'] + '/' + df_transfer['jpg_name']
show_transfer_cols = ['jpg_name', 'train/val/test', 'folder_label', 'original_image_path', 'new_image_path']
df_transfer[show_transfer_cols].head()
# Out:
#            jpg_name train/val/test folder_label         original_image_path  \
# 0   10007_225_C.jpg  train          0_crossing   mini-crops/10007_225_C.jpg
# 1   10007_315_C.jpg  train          0_crossing   mini-crops/10007_315_C.jpg
# 11  10018_135_C.jpg  train          0_crossing   mini-crops/10018_135_C.jpg
# 15  10039_135_C.jpg  train          0_crossing   mini-crops/10039_135_C.jpg
# 17  10076_315_C.jpg  train          0_crossing   mini-crops/10076_315_C.jpg
#
#                                                        new_image_path
# 0   mini-crops-labeled/crossing-null/train/0_crossing/10007_225_C.jpg
# 1   mini-crops-labeled/crossing-null/train/0_crossing/10007_315_C.jpg
# 11  mini-crops-labeled/crossing-null/train/0_crossing/10018_135_C.jpg
# 15  mini-crops-labeled/crossing-null/train/0_crossing/10039_135_C.jpg
# 17  mini-crops-labeled/crossing-null/train/0_crossing/10076_315_C.jpg

# %%
df_transfer = df_transfer.reset_index(drop = True)

# %%
# Move files from outer folder to gsv folder
bucket_name = 'gsv-crops2'
s3 = boto3.resource('s3')

start = datetime.now()
print(start)
cannot_move_paths = []
for index, row in df_transfer.iterrows():
    if index % 500 == 0:
        print(f'Through {index} images at {datetime.now()}')
    # Copy to gsv folder
    old_name = str(row['original_image_path'])
    new_name = str(row['new_image_path'])
    copy_source = {
        'Bucket': bucket_name,
        'Key': old_name
    }
    try:
        s3.meta.client.copy(copy_source, bucket_name, new_name)
    except:
        print(f'Could not move {old_name} at {datetime.now()}')
        cannot_move_paths.append(old_name)
end = datetime.now()
print(end)
# Out:
# 2020-04-06 20:37:43.535112
# Through 0 images at 2020-04-06 20:37:43.539733
# Could not move mini-crops/1195_45_C.jpg at 2020-04-06 20:37:46.416377
# Could not move mini-crops/1205_135_C.jpg at 2020-04-06 20:37:47.061602
# Could not move mini-crops/15629_225_C.jpg at 2020-04-06 20:37:52.084178
# Could not move mini-crops/15629_135_C.jpg at 2020-04-06 20:37:52.097048
# Could not move mini-crops/680_315_C.jpg at 2020-04-06 20:38:15.713695
# Could not move mini-crops/680_135_C.jpg at 2020-04-06 20:38:15.728894
# Through 500 images at 2020-04-06 20:38:26.356108
# Could not move mini-crops/1205_135_D.jpg at 2020-04-06 20:38:27.737608
# Could not move mini-crops/15619_315_D.jpg at 2020-04-06 20:38:33.728908
# Could not move mini-crops/15629_315_D.jpg at 2020-04-06 20:38:33.741023
# Could not move mini-crops/15629_135_D.jpg at 2020-04-06 20:38:33.752650
# Could not move mini-crops/15976_315_D.jpg at 2020-04-06 20:38:33.831574
# Could not move mini-crops/15976_45_D.jpg at 2020-04-06 20:38:33.843583
# Could not move mini-crops/878_225_D.jpg at 2020-04-06 20:39:04.852498
# Could not move mini-crops/1195_45_B.jpg at 2020-04-06 20:39:08.525392
# Through 1000 images at 2020-04-06 20:39:08.747367
# Could not move mini-crops/1205_45_B.jpg at 2020-04-06 20:39:08.941424
# Could not move mini-crops/1205_135_B.jpg at 2020-04-06 20:39:08.980532
# Could not move mini-crops/15629_225_B.jpg at 2020-04-06 20:39:11.981658
# Could not move mini-crops/15629_45_B.jpg at 2020-04-06 20:39:11.991769
# Could not move mini-crops/15629_135_B.jpg at 2020-04-06 20:39:12.003326
# Could not move mini-crops/680_45_B.jpg at 2020-04-06 20:39:28.129588
# Could not move mini-crops/680_135_B.jpg at 2020-04-06 20:39:28.143906
# Could not move mini-crops/878_135_B.jpg at 2020-04-06 20:39:31.552493
# Could not move mini-crops/15629_225_E.jpg at 2020-04-06 20:39:37.942189
# Could not move mini-crops/15629_315_E.jpg at 2020-04-06 20:39:37.953134
# Through 1500 images at 2020-04-06 20:39:49.411658
# Could not move mini-crops/680_225_E.jpg at 2020-04-06 20:39:52.419408
# Could not move mini-crops/878_225_E.jpg at 2020-04-06 20:39:56.664925
# Could not move mini-crops/15629_225_F.jpg at 2020-04-06 20:39:59.583466
# Could not move mini-crops/15629_315_F.jpg at 2020-04-06 20:39:59.594717
# Could not move mini-crops/680_225_F.jpg at 2020-04-06 20:40:08.778516
# Could not move mini-crops/680_45_F.jpg at 2020-04-06 20:40:08.791420
# Could not move mini-crops/680_135_F.jpg at 2020-04-06 20:40:08.805448
# Could not move mini-crops/1205_45_A.jpg at 2020-04-06 20:40:11.195869
# Could not move mini-crops/1205_135_A.jpg at 2020-04-06 20:40:11.209581
# Could not move mini-crops/15629_315_A.jpg at 2020-04-06 20:40:12.721896
# Could not move mini-crops/680_45_A.jpg at 2020-04-06 20:40:21.346970
# Could not move mini-crops/680_135_A.jpg at 2020-04-06 20:40:21.360134
# Could not move mini-crops/878_135_A.jpg at 2020-04-06 20:40:23.007042
# Could not move mini-crops/945_225_D.jpg at 2020-04-06 20:40:24.433772
# Could not move mini-crops/19224_225_F.jpg at 2020-04-06 20:40:25.453831
# Could not move mini-crops/945_315_B.jpg at 2020-04-06 20:40:27.879516
# Through 2000 images at 2020-04-06 20:40:30.007605
# Could not move mini-crops/1195_315_E.jpg at 2020-04-06 20:40:30.612391
# Could not move mini-crops/19224_225_C.jpg at 2020-04-06 20:40:32.050405
# Could not move mini-crops/1042_225_E.jpg at 2020-04-06 20:40:32.689106
# Could not move mini-crops/1205_225_B.jpg at 2020-04-06 20:40:33.627338
# Could not move mini-crops/15685_225_A.jpg at 2020-04-06 20:40:34.573697
# Could not move mini-crops/945_225_C.jpg at 2020-04-06 20:40:38.811782
# Could not move mini-crops/15685_135_B.jpg at 2020-04-06 20:40:39.823200
# Could not move mini-crops/1042_315_F.jpg at 2020-04-06 20:40:40.414090
# Could not move mini-crops/15619_135_E.jpg at 2020-04-06 20:40:40.593688
# Could not move mini-crops/15685_45_E.jpg at 2020-04-06 20:40:42.368869
# Could not move mini-crops/18630_225_E.jpg at 2020-04-06 20:40:45.738262
# Could not move mini-crops/1205_225_A.jpg at 2020-04-06 20:40:47.285138
# Could not move mini-crops/945_225_F.jpg at 2020-04-06 20:40:49.107080
# Could not move mini-crops/18630_315_A.jpg at 2020-04-06 20:40:50.501552
# Could not move mini-crops/1205_45_D.jpg at 2020-04-06 20:40:51.544331
# Could not move mini-crops/1042_135_D.jpg at 2020-04-06 20:40:51.555656
# Could not move mini-crops/945_45_C.jpg at 2020-04-06 20:40:51.567520
# Could not move mini-crops/19224_225_D.jpg at 2020-04-06 20:40:54.642956
# Could not move mini-crops/1195_315_D.jpg at 2020-04-06 20:40:57.844549
# Could not move mini-crops/15629_315_C.jpg at 2020-04-06 20:41:06.385155
# Could not move mini-crops/945_135_A.jpg at 2020-04-06 20:41:10.110457
# Through 2500 images at 2020-04-06 20:41:10.478793
# Could not move mini-crops/878_315_D.jpg at 2020-04-06 20:41:16.672093
# Could not move mini-crops/1205_45_C.jpg at 2020-04-06 20:41:17.467003
# Could not move mini-crops/1205_45_F.jpg at 2020-04-06 20:41:19.219489
# Could not move mini-crops/680_45_E.jpg at 2020-04-06 20:41:23.785400
# Could not move mini-crops/1205_315_C.jpg at 2020-04-06 20:41:25.026681
# Could not move mini-crops/18630_45_C.jpg at 2020-04-06 20:41:29.373851
# Could not move mini-crops/1042_315_C.jpg at 2020-04-06 20:41:32.611895
# Could not move mini-crops/15619_225_D.jpg at 2020-04-06 20:41:33.142857
# Could not move mini-crops/15685_135_A.jpg at 2020-04-06 20:41:33.889708
# Could not move mini-crops/15629_45_E.jpg at 2020-04-06 20:41:34.384461
# Could not move mini-crops/18630_45_E.jpg at 2020-04-06 20:41:41.347856
# Could not move mini-crops/19224_135_B.jpg at 2020-04-06 20:41:44.115352
# Could not move mini-crops/878_225_B.jpg at 2020-04-06 20:41:44.569558
# Could not move mini-crops/15619_135_D.jpg at 2020-04-06 20:41:49.028771
# Through 3000 images at 2020-04-06 20:41:51.075627
# Could not move mini-crops/15619_225_C.jpg at 2020-04-06 20:41:51.548622
# Could not move mini-crops/1042_135_E.jpg at 2020-04-06 20:41:52.012956
# Could not move mini-crops/15685_225_E.jpg at 2020-04-06 20:42:06.844297
# Could not move mini-crops/680_225_C.jpg at 2020-04-06 20:42:07.110280
# Could not move mini-crops/18630_45_D.jpg at 2020-04-06 20:42:09.499055
# Could not move mini-crops/15976_135_F.jpg at 2020-04-06 20:42:15.902237
# Could not move mini-crops/15685_225_D.jpg at 2020-04-06 20:42:21.821513
# Could not move mini-crops/945_135_B.jpg at 2020-04-06 20:42:22.491971
# Could not move mini-crops/1205_315_B.jpg at 2020-04-06 20:42:25.226453
# Could not move mini-crops/18630_135_B.jpg at 2020-04-06 20:42:25.402750
# Could not move mini-crops/15685_315_C.jpg at 2020-04-06 20:42:25.582133
# Could not move mini-crops/1205_135_F.jpg at 2020-04-06 20:42:28.930572
# Could not move mini-crops/15629_135_F.jpg at 2020-04-06 20:42:29.089559
# Through 3500 images at 2020-04-06 20:42:31.994532
# Could not move mini-crops/1042_315_A.jpg at 2020-04-06 20:42:32.082174
# Could not move mini-crops/1205_225_C.jpg at 2020-04-06 20:42:33.588883
# Could not move mini-crops/15685_315_A.jpg at 2020-04-06 20:42:35.862748
# Could not move mini-crops/1195_225_F.jpg at 2020-04-06 20:42:36.288544
# Could not move mini-crops/1195_135_A.jpg at 2020-04-06 20:42:36.503039
# Could not move mini-crops/15619_45_C.jpg at 2020-04-06 20:42:39.986977
# Could not move mini-crops/15619_315_A.jpg at 2020-04-06 20:42:43.535329
# Could not move mini-crops/18630_45_F.jpg at 2020-04-06 20:42:44.329736
# Could not move mini-crops/18630_225_C.jpg at 2020-04-06 20:42:47.480239
# Could not move mini-crops/15976_45_B.jpg at 2020-04-06 20:42:50.574336
# Could not move mini-crops/1042_225_B.jpg at 2020-04-06 20:42:50.758593
# Could not move mini-crops/18630_135_E.jpg at 2020-04-06 20:42:51.555239
# Could not move mini-crops/18630_315_C.jpg at 2020-04-06 20:42:52.473115
# Could not move mini-crops/878_315_A.jpg at 2020-04-06 20:42:55.088254
# Could not move mini-crops/680_315_D.jpg at 2020-04-06 20:42:59.593693
# Could not move mini-crops/19224_315_D.jpg at 2020-04-06 20:43:02.867685
# Could not move mini-crops/1042_225_D.jpg at 2020-04-06 20:43:07.011079
# Through 4000 images at 2020-04-06 20:43:12.144123
# Could not move mini-crops/1205_225_D.jpg at 2020-04-06 20:43:12.945471
# Could not move mini-crops/1042_135_B.jpg at 2020-04-06 20:43:13.475227
# Could not move mini-crops/19224_225_B.jpg at 2020-04-06 20:43:15.688483
# Could not move mini-crops/18630_225_D.jpg at 2020-04-06 20:43:17.400761
# Could not move mini-crops/1042_45_B.jpg at 2020-04-06 20:43:19.030325
# Could not move mini-crops/15976_135_C.jpg at 2020-04-06 20:43:19.266236
# Could not move mini-crops/1042_225_A.jpg at 2020-04-06 20:43:20.548858
# Through 4500 images at 2020-04-06 20:43:53.256581
# Through 5000 images at 2020-04-06 20:44:33.884108
# Through 5500 images at 2020-04-06 20:45:16.099691
# 2020-04-06 20:45:24.738598

# %%
df_can_move = df_transfer.loc[~df_transfer['original_image_path'].isin(cannot_move_paths)]
df_can_move.to_csv('crossingnull-crops-successful-move.csv', index = False)
df_can_move.groupby(['train/val/test', 'folder_label'])['jpg_name'].count().reset_index()
# Out:
#   train/val/test folder_label  jpg_name
# 0  test           0_crossing   337
# 1  test           1_null       400
# 2  train          0_crossing   1886
# 3  train          1_null       2125
# 4  validation     0_crossing   336
# 5  validation     1_null       400

# %%
import os
import s3fs # for reading from S3FileSystem

# %%
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/classify-streetview/model5-cross-null-resnet34'

# %%
# !aws s3 cp s3://gsv-crops2/mini-crops-labeled/0413-crossing-null /home/ec2-user/SageMaker/classify-streetview/images-eval-crossing-null --recursive
# Out:
# download: s3://gsv-crops2/mini-crops-labeled/0413-crossing-null/train/0_crossing/10007_315_C.jpg to ../images-eval-crossing-null/train/0_crossing/10007_315_C.jpg
# download: s3://gsv-crops2/mini-crops-labeled/0413-crossing-null/train/0_crossing/10007_225_D.jpg to ../images-eval-crossing-null/train/0_crossing/10007_225_D.jpg
# download: s3://gsv-crops2/mini-crops-labeled/0413-crossing-null/train/0_crossing/10007_225_C.jpg to ../images-eval-crossing-null/train/0_crossing/10007_225_C.jpg
# download: s3://gsv-crops2/mini-crops-labeled/0413-crossing-null/train/0_crossing/10007_315_B.jpg to ../images-eval-crossing-null/train/0_crossing/10007_315_B.jpg
# download: s3://gsv-crops2/mini-crops-labeled/0413-crossing-null/train/0_crossing/10018_45_D.jpg to ../images-eval-crossing-null/train/0_crossing/10018_45_D.jpg
# download: s3://gsv-crops2/mini-crops-labeled/0413-crossing-null/train/0_crossing/10018_45_E.jpg to ../images-eval-crossing-null/train/0_crossing/10018_45_E.jpg
# ...

# %% [markdown]
# # Copy Missing vs Present to SageMAker
#
# From S3 `s3://gsv-crops2/mini-crops-labeled/missing-present-2split/`
# Into the SageMaker images-missing-present-2split folder

# %%
import os
import s3fs # for reading from S3FileSystem

# %%
#import shutil
#shutil.rmtree('/home/ec2-user/SageMaker/classify-streetview/mini-balanced-images')

# %%
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/classify-streetview/model6-missing-present-from-crossing'

# %%
# !aws s3 cp s3://gsv-crops2/mini-crops-labeled/missing-present-2split /home/ec2-user/SageMaker/classify-streetview/images-missing-present-2split --recursive
# Out:
# download: s3://gsv-crops2/mini-crops-labeled/missing-present-2split/train/0_missing/10076_315_E.jpg to ../images-missing-present-2split/train/0_missing/10076_315_E.jpg
# download: s3://gsv-crops2/mini-crops-labeled/missing-present-2split/train/0_missing/10076_315_D.jpg to ../images-missing-present-2split/train/0_missing/10076_315_D.jpg
# download: s3://gsv-crops2/mini-crops-labeled/missing-present-2split/train/0_missing/10702_315_B.jpg to ../images-missing-present-2split/train/0_missing/10702_315_B.jpg
# download: s3://gsv-crops2/mini-crops-labeled/missing-present-2split/train/0_missing/10076_315_A.jpg to ../images-missing-present-2split/train/0_missing/10076_315_A.jpg
# download: s3://gsv-crops2/mini-crops-labeled/missing-present-2split/train/0_missing/16258_135_C.jpg to ../images-missing-present-2split/train/0_missing/16258_135_C.jpg
# ...
